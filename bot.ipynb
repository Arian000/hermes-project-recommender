# %%
import asyncio
from aiogram import Bot, Dispatcher, types

API_TOKEN = ''

# Initialize bot and dispatcher
bot = Bot(token=API_TOKEN)
dp = Dispatcher(bot)

@dp.message_handler()
async def handle_message(message: types.Message):
    filename = f"{message.text}.csv"

async def on_startup(dp):
    await bot.send_message('Your bot started')

async def on_shutdown(dp):
    await bot.send_message('Your bot stopped')

if __name__ == '__main__':
    from aiogram import executor

    executor.start_polling(dp, on_startup=on_startup, on_shutdown=on_shutdown)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\aiogram\utils\executor.py:320, in Executor.start_polling(self, reset_webhook, timeout, relax, fast, allowed_updates)
#     319 try:
# --> 320     loop.run_until_complete(self._startup_polling())
#     321     loop.create_task(self.dispatcher.start_polling(reset_webhook=reset_webhook, timeout=timeout,
#     322                                                    relax=relax, fast=fast, allowed_updates=allowed_updates))
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:629, in BaseEventLoop.run_until_complete(self, future)
#     628 self._check_closed()
# --> 629 self._check_running()
#     631 new_task = not futures.isfuture(future)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:588, in BaseEventLoop._check_running(self)
#     587 if self.is_running():
# --> 588     raise RuntimeError('This event loop is already running')
#     589 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 31
#      28 if __name__ == '__main__':
#      29     from aiogram import executor
# ---> 31     executor.start_polling(dp, on_startup=on_startup, on_shutdown=on_shutdown)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\aiogram\utils\executor.py:45, in start_polling(dispatcher, loop, skip_updates, reset_webhook, on_startup, on_shutdown, timeout, relax, fast, allowed_updates)
#      42 executor = Executor(dispatcher, skip_updates=skip_updates, loop=loop)
#      43 _setup_callbacks(executor, on_startup, on_shutdown)
# ---> 45 executor.start_polling(
#      46     reset_webhook=reset_webhook,
#      47     timeout=timeout,
#      48     relax=relax,
#      49     fast=fast,
#      50     allowed_updates=allowed_updates
#      51 )
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\aiogram\utils\executor.py:328, in Executor.start_polling(self, reset_webhook, timeout, relax, fast, allowed_updates)
#     326     pass
#     327 finally:
# --> 328     loop.run_until_complete(self._shutdown_polling())
#     329     log.warning("Goodbye!")
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:629, in BaseEventLoop.run_until_complete(self, future)
#     618 """Run until the Future is done.
#     619
#     620 If the argument is a coroutine, it is wrapped in a Task.
#    (...)
#     626 Return the Future's result, or raise its exception.
#     627 """
#     628 self._check_closed()
# --> 629 self._check_running()
#     631 new_task = not futures.isfuture(future)
#     632 future = tasks.ensure_future(future, loop=self)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:588, in BaseEventLoop._check_running(self)
#     586 def _check_running(self):
#     587     if self.is_running():
# --> 588         raise RuntimeError('This event loop is already running')
#     589     if events._get_running_loop() is not None:
#     590         raise RuntimeError(
#     591             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
